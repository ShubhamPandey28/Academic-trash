# %%
from model import data_analysis_model as DAM, data_analysis_model_sklearn as DAMsk
import pandas as pd


data1 = pd.read_csv("data.csv")
data2 = pd.read_csv("data.csv")
data3 = pd.read_csv("data.csv")
mdl1 = DAM(data1)
mdl2 = DAMsk(data2)
mdl3 = DAM(data3)

# %%
mdl1.boxplot("pH")

# %%
mdl1.replace_outliers_by_median_all()
# Out:
# /home/dark_matter/MAIN/Academics/Academics/IC272/lab3/model.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.dataframe[attribute_name][i] = median

# %%
mdl1.boxplot_all()

# %%
mdl1.boxplot("pH")

# %%
for att in mdl3.attributes:
    print(mdl3.range(att))
# Out:
# [3.95, 12.349999999999998]
# [0.015000000000000013, 1.0150000000000001]
# [-0.4049999999999999, 0.9149999999999999]
# [0.8499999999999996, 3.6500000000000004]
# [0.04000000000000002, 0.11999999999999998]
# [-14.0, 42.0]
# [-38.0, 122.0]
# [0.9922400000000002, 1.0011999999999999]
# [2.925, 3.6849999999999996]
# [0.28000000000000014, 0.9999999999999999]
# [7.1000000000000005, 13.5]
# [3.5, 7.5]
